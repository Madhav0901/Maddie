# %%
import pandas as pd

# Correct path format for Windows
data = pd.read_csv("C:/Users/madha/Desktop/scripts/SeoulBikeData.csv",encoding='latin1')

print(data.head())  # View the first few rows
print(data.info())  # Column types and non-null counts
print(data.describe())  # Statistical summary of numeric columns
print(data.isnull().sum())
# Out:
#          Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0  01/12/2017                254     0             -5.2           37
# 1  01/12/2017                204     1             -5.5           38
# 2  01/12/2017                173     2             -6.0           39
# 3  01/12/2017                107     3             -6.2           40
# 4  01/12/2017                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...

# %%
import pandas as pd

# Correct path format for Windows
data = pd.read_csv("C:/Users/madha/Desktop/scripts/SeoulBikeData.csv",encoding='latin1')

print(data.head())  # View the first few rows
print(data.info())  # Column types and non-null counts
print(data.describe())  # Statistical summary of numeric columns
print(data.isnull().sum())
data.dropna(inplace=True)  # Example: Remove rows with missing values
# Out:
#          Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0  01/12/2017                254     0             -5.2           37
# 1  01/12/2017                204     1             -5.5           38
# 2  01/12/2017                173     2             -6.0           39
# 3  01/12/2017                107     3             -6.2           40
# 4  01/12/2017                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...

# %%
import pandas as pd

# Correct path format for Windows
data = pd.read_csv("C:/Users/madha/Desktop/scripts/SeoulBikeData.csv",encoding='latin1')

print(data.head())  # View the first few rows
print(data.info())  # Column types and non-null counts
print(data.describe())  # Statistical summary of numeric columns
print(data.isnull().sum())
data.dropna(inplace=True)  # Example: Remove rows with missing values
data['Date'] = pd.to_datetime(data['Date'],dayfirst=True)
data['Hour'] = data['Date'].dt.hour
data['DayOfWeek'] = data['Date'].dt.dayofweek
data['Month'] = data['Date'].dt.month
print(data.head())
# Out:
#          Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0  01/12/2017                254     0             -5.2           37
# 1  01/12/2017                204     1             -5.5           38
# 2  01/12/2017                173     2             -6.0           39
# 3  01/12/2017                107     3             -6.2           40
# 4  01/12/2017                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...

# %%
import pandas as pd

# Correct path format for Windows
data = pd.read_csv("C:/Users/madha/Desktop/scripts/SeoulBikeData.csv",encoding='latin1')

print(data.head())  # View the first few rows
print(data.info())  # Column types and non-null counts
print(data.describe())  # Statistical summary of numeric columns
print(data.isnull().sum())
data.dropna(inplace=True)  # Example: Remove rows with missing values
data['Date'] = pd.to_datetime(data['Date'],dayfirst=True)
data['Hour'] = data['Date'].dt.hour
data['DayOfWeek'] = data['Date'].dt.dayofweek
data['Month'] = data['Date'].dt.month
# Normalize wind speed to km/h (assume the column name is 'Wind speed')
if 'Wind speed (m/s)' in data.columns:  # Check if 'Wind speed' column exists
    data['Wind speed (km/h)'] = data['Wind speed (m/s)'] * 3.6
    print("Wind speed converted to km/h.")
else:
    print("Column 'Wind speed' not found in the dataset.")
print(data.head())
# Out:
#          Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0  01/12/2017                254     0             -5.2           37
# 1  01/12/2017                204     1             -5.5           38
# 2  01/12/2017                173     2             -6.0           39
# 3  01/12/2017                107     3             -6.2           40
# 4  01/12/2017                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Correct path format for Windows
data = pd.read_csv("C:/Users/madha/Desktop/scripts/SeoulBikeData.csv",encoding='latin1')

print(data.head())  # View the first few rows
print(data.info())  # Column types and non-null counts
print(data.describe())  # Statistical summary of numeric columns
print(data.isnull().sum())
data.dropna(inplace=True)  # Example: Remove rows with missing values
data['Date'] = pd.to_datetime(data['Date'],dayfirst=True)
data['Hour'] = data['Date'].dt.hour
data['DayOfWeek'] = data['Date'].dt.dayofweek
data['Month'] = data['Date'].dt.month
# Normalize wind speed to km/h (assume the column name is 'Wind speed')
if 'Wind speed (m/s)' in data.columns:  # Check if 'Wind speed' column exists
    data['Wind speed (km/h)'] = data['Wind speed (m/s)'] * 3.6
    print("Wind speed converted to km/h.")
else:
    print("Column 'Wind speed' not found in the dataset.")
print(data.head())

data.groupby('Hour')['Rented Bike Count'].sum().plot(kind='line', title='Rides by Hour')
plt.show()
data.groupby('DayOfWeek')['Rented Bike Count'].sum().plot(kind='line', title='Rides by Week')
plt.show()
data.groupby('Month')['Rented Bike Count'].sum().plot(kind='line', title='Rides by Month')
plt.show()
# Out:
#          Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0  01/12/2017                254     0             -5.2           37
# 1  01/12/2017                204     1             -5.5           38
# 2  01/12/2017                173     2             -6.0           39
# 3  01/12/2017                107     3             -6.2           40
# 4  01/12/2017                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...

# %%
print(data.columns)
# Out:
# Index(['Date', 'Rented Bike Count', 'Hour', 'Temperature(°C)', 'Humidity(%)',
#        'Wind speed (m/s)', 'Visibility (10m)', 'Dew point temperature(°C)',
#        'Solar Radiation (MJ/m2)', 'Rainfall(mm)', 'Snowfall (cm)', 'Seasons',
#        'Holiday', 'Functioning Day', 'DayOfWeek', 'Month',
#        'Wind speed (km/h)'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Correct path format for Windows
data = pd.read_csv("C:/Users/madha/Desktop/scripts/SeoulBikeData.csv",encoding='latin1')

print(data.head())  # View the first few rows
print(data.info())  # Column types and non-null counts
print(data.describe())  # Statistical summary of numeric columns
print(data.isnull().sum())
data.dropna(inplace=True)  # Example: Remove rows with missing values
data['Date'] = pd.to_datetime(data['Date'],dayfirst=True)
data['Hour'] = data['Date'].dt.hour
data['DayOfWeek'] = data['Date'].dt.dayofweek
data['Month'] = data['Date'].dt.month
# Normalize wind speed to km/h (assume the column name is 'Wind speed')
if 'Wind speed (m/s)' in data.columns:  # Check if 'Wind speed' column exists
    data['Wind speed (km/h)'] = data['Wind speed (m/s)'] * 3.6
    print("Wind speed converted to km/h.")
else:
    print("Column 'Wind speed' not found in the dataset.")
print(data.head())

data.groupby('Hour')['Rented Bike Count'].sum().plot(kind='bar', title='Rides by Hour')
plt.show()
data.groupby('DayOfWeek')['Rented Bike Count'].sum().plot(kind='bar', title='Rides by Week')
plt.show()
data.groupby('Month')['Rented Bike Count'].sum().plot(kind='line', title='Rides by Month')
plt.show()
data.groupby('Seasons')['Rented Bike Count'].sum().plot(kind='line', title='Rides by Month')
plt.show()
sns.scatterplot(data=data, x='Temperature(°C)', y='Rented Bike Count')
sns.scatterplot(data=data, x='Rainfall(mm)', y='Rented Bike Count')
sns.scatterplot(data=data, x='Snowfall (cm)', y='Rented Bike Count')
# Out:
#          Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0  01/12/2017                254     0             -5.2           37
# 1  01/12/2017                204     1             -5.5           38
# 2  01/12/2017                173     2             -6.0           39
# 3  01/12/2017                107     3             -6.2           40
# 4  01/12/2017                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Correct path format for Windows
data = pd.read_csv("C:/Users/madha/Desktop/scripts/SeoulBikeData.csv",encoding='latin1')

print(data.head())  # View the first few rows
print(data.info())  # Column types and non-null counts
print(data.describe())  # Statistical summary of numeric columns
print(data.isnull().sum())
data.dropna(inplace=True)  # Example: Remove rows with missing values
data['Date'] = pd.to_datetime(data['Date'],dayfirst=True)
data['Hour'] = data['Date'].dt.hour
data['DayOfWeek'] = data['Date'].dt.dayofweek
data['Month'] = data['Date'].dt.month
# Normalize wind speed to km/h (assume the column name is 'Wind speed')
if 'Wind speed (m/s)' in data.columns:  # Check if 'Wind speed' column exists
    data['Wind speed (km/h)'] = data['Wind speed (m/s)'] * 3.6
    print("Wind speed converted to km/h.")
else:
    print("Column 'Wind speed' not found in the dataset.")
print(data.head())

data.groupby('Hour')['Rented Bike Count'].sum().plot(kind='bar', title='Rides by Hour')
plt.show()
data.groupby('DayOfWeek')['Rented Bike Count'].sum().plot(kind='bar', title='Rides by Week')
plt.show()
data.groupby('Month')['Rented Bike Count'].sum().plot(kind='line', title='Rides by Month')
plt.show()
data.groupby('Seasons')['Rented Bike Count'].sum().plot(kind='line', title='Rides by Month')
plt.show()

sns.scatterplot(data=data, x='Rainfall(mm)', y='Rented Bike Count')
# Out:
#          Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0  01/12/2017                254     0             -5.2           37
# 1  01/12/2017                204     1             -5.5           38
# 2  01/12/2017                173     2             -6.0           39
# 3  01/12/2017                107     3             -6.2           40
# 4  01/12/2017                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Correct path format for Windows
data = pd.read_csv("C:/Users/madha/Desktop/scripts/SeoulBikeData.csv",encoding='latin1')

print(data.head())  # View the first few rows
print(data.info())  # Column types and non-null counts
print(data.describe())  # Statistical summary of numeric columns
print(data.isnull().sum())
data.dropna(inplace=True)  # Example: Remove rows with missing values
data['Date'] = pd.to_datetime(data['Date'],dayfirst=True)
data['Hour'] = data['Date'].dt.hour
data['DayOfWeek'] = data['Date'].dt.dayofweek
data['Month'] = data['Date'].dt.month
# Normalize wind speed to km/h (assume the column name is 'Wind speed')
if 'Wind speed (m/s)' in data.columns:  # Check if 'Wind speed' column exists
    data['Wind speed (km/h)'] = data['Wind speed (m/s)'] * 3.6
    print("Wind speed converted to km/h.")
else:
    print("Column 'Wind speed' not found in the dataset.")
print(data.head())

data.groupby('Hour')['Rented Bike Count'].sum().plot(kind='bar', title='Rides by Hour')
plt.show()
data.groupby('DayOfWeek')['Rented Bike Count'].sum().plot(kind='bar', title='Rides by Week')
plt.show()
data.groupby('Month')['Rented Bike Count'].sum().plot(kind='line', title='Rides by Month')
plt.show()
data.groupby('Seasons')['Rented Bike Count'].sum().plot(kind='line', title='Rides by Month')
plt.show()


sns.scatterplot(data=data, x='Snowfall (cm)', y='Rented Bike Count')
# Out:
#          Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0  01/12/2017                254     0             -5.2           37
# 1  01/12/2017                204     1             -5.5           38
# 2  01/12/2017                173     2             -6.0           39
# 3  01/12/2017                107     3             -6.2           40
# 4  01/12/2017                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Correct path format for Windows
data = pd.read_csv("C:/Users/madha/Desktop/scripts/SeoulBikeData.csv",encoding='latin1')

print(data.head())  # View the first few rows
print(data.info())  # Column types and non-null counts
print(data.describe())  # Statistical summary of numeric columns
print(data.isnull().sum())
data.dropna(inplace=True)  # Example: Remove rows with missing values
data['Date'] = pd.to_datetime(data['Date'],dayfirst=True)
data['Hour'] = data['Date'].dt.hour
data['DayOfWeek'] = data['Date'].dt.dayofweek
data['Month'] = data['Date'].dt.month
# Normalize wind speed to km/h (assume the column name is 'Wind speed')
if 'Wind speed (m/s)' in data.columns:  # Check if 'Wind speed' column exists
    data['Wind speed (km/h)'] = data['Wind speed (m/s)'] * 3.6
    print("Wind speed converted to km/h.")
else:
    print("Column 'Wind speed' not found in the dataset.")
print(data.head())

data.groupby('Hour')['Rented Bike Count'].sum().plot(kind='bar', title='Rides by Hour')
plt.show()
data.groupby('DayOfWeek')['Rented Bike Count'].sum().plot(kind='bar', title='Rides by Week')
plt.show()
data.groupby('Month')['Rented Bike Count'].sum().plot(kind='line', title='Rides by Month')
plt.show()
data.groupby('Seasons')['Rented Bike Count'].sum().plot(kind='line', title='Rides by Month')
plt.show()
sns.scatterplot(data=data, x='Temperature(°C)', y='Rented Bike Count')
# Out:
#          Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0  01/12/2017                254     0             -5.2           37
# 1  01/12/2017                204     1             -5.5           38
# 2  01/12/2017                173     2             -6.0           39
# 3  01/12/2017                107     3             -6.2           40
# 4  01/12/2017                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Correct path format for Windows
data = pd.read_csv("C:/Users/madha/Desktop/scripts/SeoulBikeData.csv",encoding='latin1')

print(data.head())  # View the first few rows
print(data.info())  # Column types and non-null counts
print(data.describe())  # Statistical summary of numeric columns
print(data.isnull().sum())
data.dropna(inplace=True)  # Example: Remove rows with missing values
data['Date'] = pd.to_datetime(data['Date'],dayfirst=True)
data['Hour'] = data['Date'].dt.hour
data['DayOfWeek'] = data['Date'].dt.dayofweek
data['Month'] = data['Date'].dt.month
# Normalize wind speed to km/h (assume the column name is 'Wind speed')
if 'Wind speed (m/s)' in data.columns:  # Check if 'Wind speed' column exists
    data['Wind speed (km/h)'] = data['Wind speed (m/s)'] * 3.6
    print("Wind speed converted to km/h.")
else:
    print("Column 'Wind speed' not found in the dataset.")
print(data.head())

data.groupby('Hour')['Rented Bike Count'].sum().plot(kind='bar', title='Rides by Hour')
plt.show()
data.groupby('DayOfWeek')['Rented Bike Count'].sum().plot(kind='bar', title='Rides by Week')
plt.show()
data.groupby('Month')['Rented Bike Count'].sum().plot(kind='line', title='Rides by Month')
plt.show()
data.groupby('Seasons')['Rented Bike Count'].sum().plot(kind='line', title='Rides by Month')
plt.show()
sns.scatterplot(data=data, x='Temperature(°C)', y='Rented Bike Count')
sns.scatterplot(data=data, x='Rainfall(mm)', y='Rented Bike Count')
sns.scatterplot(data=data, x='Snowfall (cm)', y='Rented Bike Count')
sns.boxplot(data=data, x='DayOfWeek', y='Rented Bike Count')
# Out:
#          Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0  01/12/2017                254     0             -5.2           37
# 1  01/12/2017                204     1             -5.5           38
# 2  01/12/2017                173     2             -6.0           39
# 3  01/12/2017                107     3             -6.2           40
# 4  01/12/2017                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Correct path format for Windows
data = pd.read_csv("C:/Users/madha/Desktop/scripts/SeoulBikeData.csv",encoding='latin1')

print(data.head())  # View the first few rows
print(data.info())  # Column types and non-null counts
print(data.describe())  # Statistical summary of numeric columns
print(data.isnull().sum())
data.dropna(inplace=True)  # Example: Remove rows with missing values
data['Date'] = pd.to_datetime(data['Date'],dayfirst=True)
data['Hour'] = data['Date'].dt.hour
data['DayOfWeek'] = data['Date'].dt.dayofweek
data['Month'] = data['Date'].dt.month
# Normalize wind speed to km/h (assume the column name is 'Wind speed')
if 'Wind speed (m/s)' in data.columns:  # Check if 'Wind speed' column exists
    data['Wind speed (km/h)'] = data['Wind speed (m/s)'] * 3.6
    print("Wind speed converted to km/h.")
else:
    print("Column 'Wind speed' not found in the dataset.")
print(data.head())

data.groupby('Hour')['Rented Bike Count'].sum().plot(kind='bar', title='Rides by Hour')
plt.show()
data.groupby('DayOfWeek')['Rented Bike Count'].sum().plot(kind='bar', title='Rides by Week')
plt.show()
data.groupby('Month')['Rented Bike Count'].sum().plot(kind='line', title='Rides by Month')
plt.show()
data.groupby('Seasons')['Rented Bike Count'].sum().plot(kind='line', title='Rides by Month')
plt.show()
sns.scatterplot(data=data, x='Temperature(°C)', y='Rented Bike Count')
sns.scatterplot(data=data, x='Rainfall(mm)', y='Rented Bike Count')
sns.scatterplot(data=data, x='Snowfall (cm)', y='Rented Bike Count')
sns.barplot(data=data, x='DayOfWeek', y='Rented Bike Count')
# Out:
#          Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0  01/12/2017                254     0             -5.2           37
# 1  01/12/2017                204     1             -5.5           38
# 2  01/12/2017                173     2             -6.0           39
# 3  01/12/2017                107     3             -6.2           40
# 4  01/12/2017                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# Correct path format for Windows
data = pd.read_csv("C:/Users/madha/Desktop/scripts/SeoulBikeData.csv",encoding='latin1')

print(data.head())  # View the first few rows
print(data.info())  # Column types and non-null counts
print(data.describe())  # Statistical summary of numeric columns
print(data.isnull().sum())
data.dropna(inplace=True)  # Example: Remove rows with missing values
data['Date'] = pd.to_datetime(data['Date'],dayfirst=True)
data['Hour'] = data['Date'].dt.hour
data['DayOfWeek'] = data['Date'].dt.dayofweek
data['Month'] = data['Date'].dt.month
# Normalize wind speed to km/h (assume the column name is 'Wind speed')
if 'Wind speed (m/s)' in data.columns:  # Check if 'Wind speed' column exists
    data['Wind speed (km/h)'] = data['Wind speed (m/s)'] * 3.6
    print("Wind speed converted to km/h.")
else:
    print("Column 'Wind speed' not found in the dataset.")
print(data.head())

data.groupby('Hour')['Rented Bike Count'].sum().plot(kind='bar', title='Rides by Hour')
plt.show()
data.groupby('DayOfWeek')['Rented Bike Count'].sum().plot(kind='bar', title='Rides by Week')
plt.show()
data.groupby('Month')['Rented Bike Count'].sum().plot(kind='line', title='Rides by Month')
plt.show()
data.groupby('Seasons')['Rented Bike Count'].sum().plot(kind='line', title='Rides by Month')
plt.show()
sns.scatterplot(data=data, x='Temperature(°C)', y='Rented Bike Count')
sns.scatterplot(data=data, x='Rainfall(mm)', y='Rented Bike Count')
sns.scatterplot(data=data, x='Snowfall (cm)', y='Rented Bike Count')
sns.barplot(data=data, x='DayOfWeek', y='Rented Bike Count')


fig = px.line(data, x='Hour', y='Rented Bike Count', title='Hourly Rides')
fig.show()
# Out:
#          Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0  01/12/2017                254     0             -5.2           37
# 1  01/12/2017                204     1             -5.5           38
# 2  01/12/2017                173     2             -6.0           39
# 3  01/12/2017                107     3             -6.2           40
# 4  01/12/2017                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...
